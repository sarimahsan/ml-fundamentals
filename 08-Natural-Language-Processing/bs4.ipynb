# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("Resume.csv")

# Convert HTML to plain text
def clean_html(html_text):
    if pd.isna(html_text):  # handle empty cells
        return ""
    soup = BeautifulSoup(html_text, "html.parser")
    text = soup.get_text(separator=" ")
    text = re.sub(r'\s+', ' ', text)  # remove extra spaces
    return text.strip()

df["clean_text"] = df["Resume_html"].apply(clean_html)

X = df['clean_text']
y=df['Category']

# %%
vectorizer = TfidfVectorizer(max_features=5000)
X_vec = vectorizer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state=42)

# %%
clf = LogisticRegression(max_iter=500)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                         precision    recall  f1-score   support
#
#             ACCOUNTANT       0.83      0.83      0.83        29
#               ADVOCATE       0.56      0.60      0.58        30
#            AGRICULTURE       0.25      0.12      0.17         8
#                APPAREL       0.54      0.35      0.42        20
#                   ARTS       0.17      0.17      0.17        18
#             AUTOMOBILE       0.00      0.00      0.00         6
#               AVIATION       0.72      0.86      0.78        21
#                BANKING       0.73      0.70      0.71        23
#                    BPO       0.00      0.00      0.00         2
#   BUSINESS-DEVELOPMENT       0.76      0.59      0.67        27
#                   CHEF       0.85      0.71      0.77        24
#           CONSTRUCTION       0.90      0.76      0.83        34
#             CONSULTANT       0.44      0.20      0.28        20
#               DESIGNER       0.75      0.79      0.77        19
#          DIGITAL-MEDIA       0.94      0.68      0.79        25
#            ENGINEERING       0.48      0.67      0.56        21
#                FINANCE       0.59      0.68      0.63        19
#                FITNESS       1.00      0.53      0.69        19
#             HEALTHCARE       0.33      0.45      0.38        20
#                     HR       0.68      0.83      0.75        18
# INFORMATION-TECHNOLOGY       0.55      0.88      0.68        26
#       PUBLIC-RELATIONS       0.55      0.71      0.62        17
#                  SALES       0.56      0.76      0.65        29
#                TEACHER       0.62      0.68      0.65        22
#
#               accuracy                           0.63       497
#              macro avg       0.58      0.56      0.56       497
#           weighted avg       0.64      0.63      0.63       497
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def predict_resume(text):
    text_vec = vectorizer.transform([text])
    return clf.predict(text_vec)[0]

print(predict_resume("Experienced HR professional skilled in recruitment and onboarding."))
# Out:
# HR
