# %%
import torch
import torch.nn as nn

# Example: 32 samples, each of length 10, each word has 100 features
x = torch.randn(32, 10, 100)

lstm = nn.LSTM(input_size=100, hidden_size=64, batch_first=True)

output, (h, c) = lstm(x)
print(output)
# Out:
# tensor([[[ 1.2093e-01, -9.3114e-02, -3.5557e-02,  ..., -1.3715e-01,
#           -1.4155e-01, -4.8189e-03],
#          [ 1.9232e-01, -9.5156e-02, -5.8569e-02,  ...,  7.9308e-03,
#           -8.8404e-02,  3.7716e-02],
#          [ 1.2032e-01, -1.6617e-01, -2.3154e-01,  ...,  1.1167e-01,
#           -1.1314e-01,  1.8992e-02],
#          ...,
#          [ 2.2576e-01,  6.5495e-02,  4.8436e-02,  ..., -2.6976e-02,
#           -4.4737e-02,  2.2875e-01],
#          [-3.6203e-02, -3.2917e-03, -1.1406e-01,  ..., -5.0010e-02,
#            8.0931e-02,  4.0974e-01],
#          [-1.7158e-01,  1.3510e-01, -1.1353e-01,  ...,  1.1250e-01,
#           -2.5908e-02,  2.5587e-01]],
#
#         [[ 3.0699e-03, -6.5296e-02,  9.9608e-02,  ..., -1.1115e-01,
#            1.9643e-01, -1.3406e-01],
#          [-1.9911e-01, -2.6987e-01,  3.7577e-01,  ..., -9.8775e-02,
#            3.1172e-01, -1.1014e-01],
#          [-1.1837e-01, -3.7355e-01,  1.7507e-01,  ..., -7.2603e-02,
#            1.9755e-01,  3.5214e-01],
# ...

# %%
# Create time steps
x = np.linspace(0, 100, 500)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave Data")
plt.show()

# %%
def create_dataset(data, time_steps=10):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+time_steps])
    return np.array(X), np.array(y)

time_steps = 50
X, y = create_dataset(y, time_steps)
X = X.reshape((X.shape[0], X.shape[1], 1))  # reshape to 3D

# %%
model = Sequential([
    LSTM(50, activation='tanh', input_shape=(time_steps, 1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X, y, epochs=20, batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.0000e+00 - loss: 0.3929
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0000e+00 - loss: 0.1579
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.0169
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 0.0034
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0000e+00 - loss: 7.5665e-04
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - loss: 3.2290e-04
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 9.8971e-05
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.0000e+00 - loss: 3.6794e-05
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.0000e+00 - loss: 2.5527e-05
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.0000e+00 - loss: 2.3218e-05
# Epoch 11/20
# ...

# %%
y_pred = model.predict(X)

plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title("LSTM Prediction")
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
